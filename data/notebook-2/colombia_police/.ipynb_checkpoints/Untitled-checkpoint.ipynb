# %%
import pandas as pd 
import numpy as np 

import plotly.express as px

# %%
fifteen = pd.read_csv("violencia_intrafamiliar_2015.csv").dropna()
sixteen = pd.read_csv("violencia_intrafamiliar_2016.csv").dropna()
seventeen = pd.read_csv("violencia_intrafamiliar_2017.csv").dropna()
eighteen = pd.read_csv("violencia_intrafamiliar_2018.csv").dropna()
nineteen = pd.read_csv("violencia_intrafamiliar_2019.csv").dropna()
twenty = pd.read_csv("violencia_intrafamiliar_2020.csv").dropna()
twentyone = pd.read_csv("violencia_intrafamiliar_2021.csv").dropna()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
fifteen.groupby?
# Out:
# Signature:
# fifteen.groupby(
#     by=None,
#     axis: 'Axis' = 0,
#     level: 'Level | None' = None,
#     as_index: 'bool' = True,
#     sort: 'bool' = True,
#     group_keys: 'bool' = True,
#     squeeze: 'bool | lib.NoDefault' = <no_default>,
#     observed: 'bool' = False,
#     dropna: 'bool' = True,
# ) -> 'DataFrameGroupBy'
# Docstring:
# Group DataFrame using a mapper or by a Series of columns.
#
# A groupby operation involves some combination of splitting the
# object, applying a function, and combining the results. This can be
# used to group large amounts of data and compute operations on these
# groups.
#
# Parameters
# ----------
# by : mapping, function, label, or list of labels
#     Used to determine the groups for the groupby.
#     If ``by`` is a function, it's called on each value of the object's
#     index. If a dict or Series is passed, the Series or dict VALUES
#     will be used to determine the groups (the Series' values are first
# ...

# %%
fifteen.groupby(['DEPARTAMENTO', 'MUNICIPIO', 'GENERO']).agg('count')
# Out:
#                                             CODIGO DANE  ARMAS MEDIOS  \
# DEPARTAMENTO MUNICIPIO           GENERO
# AMAZONAS     LETICIA (CT)        FEMENINO           120           120
#                                  MASCULINO           42            42
#              PUERTO NARIÑO       FEMENINO             3             3
#                                  MASCULINO            2             2
# ANTIOQUIA    ABEJORRAL           FEMENINO             4             4
# ...                                                 ...           ...
# VAUPÉS       MITÚ (CT)           MASCULINO            1             1
# VICHADA      CUMARIBO            FEMENINO             2             2
#              PUERTO CARREÑO (CT) FEMENINO            16            16
#                                  MASCULINO            2             2
#              SANTA ROSALÍA       FEMENINO             1             1
#
#                                             FECHA HECHO  AGRUPA EDAD PERSONA  \
# ...
